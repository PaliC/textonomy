# %%
import pandas as pd

data = pd.read_csv('search_strings.csv', encoding = "ISO-8859-1")
data['item_title'] = data['item_title'].str.lower()

# %%
items = data[['item_title']]
categories = data[['category']]

# %%
import string
import re

def tokenize(text):
    text = re.sub(r'[^A-Za-z]', r' ', text)
    arr = text.split()
    arr = [x for x in arr if len(x) > 1]
    return arr

# %%
items = items.applymap(tokenize)
clean_data = items.join(categories)

# %%
clean_data.to_csv('clean_data.csv', index=False)

# %%
vocabulary = set()

for _, val in clean_data['item_title'].iteritems():
    row_set = set(val)
    vocabulary = vocabulary.union(row_set)

# %%
import csv
with open('vocabulary.csv', 'w') as outfile:
    writer = csv.writer(outfile)
    writer.writerow(list(vocabulary))

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

shuffled_data = shuffle(clean_data, random_state=0)
shuffled_data
# Out:
#                                               item_title  \
# 7446   [bluetooth, wireless, headset, stereo, headpho...
# 6520   [converse, all, star, chuck, taylor, canvas, s...
# 2157   [rgb, intel, core, gaming, pc, gtx, gb, ram, g...
# 3237    [absinthe, kit, wormwood, make, ml, mg, thujone]
# 1286   [apple, iphone, factory, unlocked, verizon, at...
# 6940   [merax, pu, leather, mesh, high, back, office,...
# 3743   [complete, tune, up, kit, for, ford, naa, side...
# 5973   [natural, pairs, thick, makeup, false, eyelash...
# 1818   [embroidered, sew, iron, on, patches, badge, f...
# 9226   [bundle, apple, ipad, mini, st, gen, gb, wi, f...
# 6236   [alpine, swiss, men, gloves, dressy, genuine, ...
# 5669   [personalized, aluminum, customized, luggage, ...
# 5667   [styles, marvel, dc, batman, iron, man, spider...
# 8452   [lumens, modes, zoomable, led, flashlight, tor...
# 1103   [iphone, xs, max, xr, plus, waterproof, dirt, ...
# 9540   [hot, in, electric, soldering, iron, tools, ki...
# 7240   [car, removal, open, tools, door, clip, kit, p...
# 982    [gremlin, hot, rod, california, car, awesome, ...
# 2378   [canon, eos, rebel, digital, slr, camera, with...
# 2917   [mb, power, supply, module, breadboard, board,...
# 9623   [soldering, iron, solder, flux, paste, helping...
# 9805   [intex, kool, splash, inflatable, play, center...
# 7267   [premium, gloss, carbon, fiber, vinyl, sticker...
# 1167   [for, apple, iphone, xs, plus, hybrid, heavy, ...
# 7037   [smok, tfv, prince, rba, mesh, max, mesh, coil...
# 5120   [sigma, mm, ex, dc, os, hsm, zoom, lens, for, ...
# 3787   [led, outdoor, fairy, curtains, string, light,...
# 5254   [to, bench, die, pipe, bender, square, rod, tu...
# 7150   [smart, finder, bluetooth, tracer, pet, child,...
# 8267   [latest, dz, bluetooth, smart, watch, camera, ...
# ...                                                  ...
# 7599   [hall, jewel, tea, autumn, leaf, smooth, top, ...
# 1871   [lot, dome, circle, clear, epoxy, stickers, fo...
# 2046   [rebelde, novela, season, telenovela, dvd, box...
# 7877   [color, station, silk, screen, printing, press...
# 4851   [apple, macbook, air, core, ghz, gb, ram, gb, ...
# 5072   [nikon, af, dx, nikkor, mm, ed, vr, lens, for,...
# 2163   [raspberry, pi, gb, ram, model, ghz, quad, cor...
# 6036   [pro, pcs, makeup, brushes, cosmetic, tool, ki...
# 6921   [pu, leather, high, back, office, chair, execu...
# 6216   [men, aluminium, polarized, colored, sunglasse...
# 11085  [women, black, ballet, flat, mary, jane, ankle...
# 537    [personalised, dummy, pacifier, soother, all, ...
# 9893   [pcs, car, motors, truck, flexible, led, strip...
# 2897   [iic, twi, sp, serial, interface, board, modul...
# 7768   [dual, lcd, digital, heat, press, machine, for...
# 2222   [dell, tower, windows, desktop, computer, pc, ...
# 10327           [star, fox, zero, star, fox, guard, wii]
# 2599   [lot, pcs, handmade, wedding, dress, party, go...
# 705    [newborn, infant, baby, boy, girl, kids, rompe...
# 3468   [intex, classic, inflatable, full, air, mattre...
# 6744   [usa, gold, bud, touch, vape, kit, mah, batter...
# 5874   [stainless, steel, push, control, wall, mount,...
# 4373   [sterling, silver, swarovski, elements, crysta...
# 7891   [sheets, sublimation, ink, heat, transfer, pap...
# 9225   [apple, ipad, air, mini, gb, gb, gb, wi, fi, c...
# 4859   [apple, macbook, white, mc, ll, gb, hdd, ghz, ...
# 3264   [bulk, pure, natural, organic, himalayan, pink...
# 9845   [camo, tri, spinner, fidget, toy, edc, hand, f...
# 10799  [zanzea, boho, summer, evening, party, sundres...
# 2732            [kibitzer, eliquid, by, five, pawns, ml]
#
#                                     category
# 7446           Portable Audio and Headphones
# 6520                              Mens Shoes
# 2157                Desktops and All-In-Ones
# 3237                      Food and Beverages
# 1286              Cell Phone and Smartphones
# 6940                        Office Furniture
# 3743   Heavy Equipment Parts and Attachments
# 5973                                  Makeup
# 1818                                  Crafts
# 9226               Tablets and eBook Readers
# 6236                         Mens Accesories
# 5669                     Luggage Accessories
# 5667                     Luggage Accessories
# 8452                          Sporting Goods
# 1103                  Cell Phone Accessories
# 9540            Tools and Workshop Equipment
# 7240       Parts and Accessories Ebay Motors
# 982                          Cars and Trucks
# 2378                         Digital Cameras
# 2917       Electrical Equipment and Supplies
# 9623            Tools and Workshop Equipment
# 9805                        Toys and Hobbies
# 7267       Parts and Accessories Ebay Motors
# 1167                  Cell Phone Accessories
# 7037              Other Consumer Electronics
# 5120                      Lenses and Filters
# 3787                Holiday and Season Decor
# 5254               Light Equipment and Tools
# 7150              Other Consumer Electronics
# 8267                           Smart Watches
# ...                                      ...
# 7599                       Pottery and Glass
# 1871                                  Crafts
# 2046                         DVDs and Movies
# 7877               Printing and Graphic Arts
# 4851                    Laptops and Netbooks
# 5072                      Lenses and Filters
# 2163                Desktops and All-In-Ones
# 6036                                  Makeup
# 6921                        Office Furniture
# 6216                         Mens Accesories
# 11085                           Womens Shoes
# 537                                     Baby
# 9893             Vehicle Electronics and GPS
# 2897       Electrical Equipment and Supplies
# 7768               Printing and Graphic Arts
# 2222                Desktops and All-In-Ones
# 10327                            Video Games
# 2599                         Dolls and Bears
# 705                Baby and Toddler Clothing
# 3468                               Furniture
# 6744        Multipurpose Batteries and Power
# 5874                        Major Appliances
# 4373                   Jewellery and Watches
# 7891               Printing and Graphic Arts
# 9225               Tablets and eBook Readers
# 4859                    Laptops and Netbooks
# 3264                      Food and Beverages
# 9845                        Toys and Hobbies
# 10799                        Womens Clothing
# 2732      E-Cigarettes Vapes and Accessories
#
# [11122 rows x 2 columns]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(shuffled_data['item_title'], shuffled_data['category'], random_state=0)
